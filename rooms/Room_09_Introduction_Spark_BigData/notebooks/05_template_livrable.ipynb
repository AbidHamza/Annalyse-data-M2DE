# %% [markdown]
# # 🎓 Livrable Final - Room 09 Spark
#
# **Nom de l'étudiant** : [VOTRE NOM ICI]
# **Prénom** : [VOTRE PRENOM ICI]
#
# ---
#
# Ce notebook unique servira de validation pour l'ensemble de la Room 09. Il regroupe les exercices clés.

# %% [markdown]
# ## Partie 1 : Les Bases (Notebook 01)
# **Consigne** : Copiez-collez ci-dessous le code qui permet de :
# 1. Initialiser une SparkSession.
# 2. Créer un DataFrame de 3 lignes (Nom, Age, Ville).
# 3. Afficher le schéma.

# %%
# VOTRE CODE PARTIE 1 ICI

# %% [markdown]
# ## Partie 2 : Manipulation (Notebook 02)
# **Consigne** : Écrivez une fonction `clean_data(df)` qui prend un DataFrame et :
# 1. Remplace les NULLs de la colonne 'prix' par 0.
# 2. Ajoute une colonne 'prix_ttc' (prix * 1.2).
# 3. Retourne le DataFrame nettoyé.

# %%
def clean_data(df):
    # VOTRE CODE PARTIE 2 ICI
    pass

# %% [markdown]
# ## Partie 3 : SQL & Window (Notebook 03)
# **Question** : Quelle est la différence entre `RANK()` et `DENSE_RANK()` ? Donnez un exemple concret en 2 lignes.

# %% [markdown]
# *[VOTRE RÉPONSE ICI]*

# %% [markdown]
# ## Partie 4 : Mini-Projet NYC Taxi (Notebook 04)
# **Consigne** : Copiez ci-dessous l'intégralité de votre code final pour le Mini-Projet.
# Il doit inclure :
# - La génération de données.
# - Le nettoyage.
# - Le calcul de vitesse moyenne.
# - L'agrégation par Zone.

# %%
# VOTRE CODE COMPLET MINI-PROJET ICI
